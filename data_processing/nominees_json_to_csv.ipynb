# %% [markdown]
# # Title

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import pathlib as path
import json

# %% [markdown]
# ## Importing Nominees File

# %%
rel_path = path.Path().absolute()
df = pd.read_json(path_or_buf = str(rel_path) + r"\oscar_acting_nominess_and_winner\nominees.json", orient = 'split')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-657873f14694> in <module>
#       1 rel_path = path.Path().absolute()
# ----> 2 df = pd.read_json(path_or_buf = str(rel_path) + r"\oscar_acting_nominess_and_winner\nominees.json", orient = 'split')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\json\json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
# ...

# %%
df
# Out:
#                                                                               1  \
# actor                         {'Richard Barthelmess': {'isWinner': False, 'f...
# actor in a leading role                                                     NaN
# actor in a supporting role                                                  NaN
# actress                       {'Louise Dresser': {'isWinner': False, 'films'...
# actress in a leading role                                                   NaN
# actress in a supporting role                                                NaN
# year                                                                       1927
#
#                                                                               2  \
# actor                         {'George Bancroft': {'isWinner': True, 'films'...
# actor in a leading role                                                     NaN
# actor in a supporting role                                                  NaN
# ...
