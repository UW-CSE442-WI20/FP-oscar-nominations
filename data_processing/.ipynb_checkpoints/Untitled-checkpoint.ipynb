# %% [markdown]
# # Title

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import pathlib as path
from google import search
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a076c57a0222> in <module>
#       1 import pandas as pd
#       2 import pathlib as path
# ----> 3 from google import search
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# ## Importing Files

# %%
rel_path = path.Path().absolute()
od = pd.read_csv(str(rel_path) + r"\raw_data\oscars-demographics.csv", sep = ';')
tr = pd.read_csv(str(rel_path) + r"\raw_data\title_ratings.tsv", sep = '\t')
mt = pd.read_csv(str(rel_path) + r"\..\src\movie_titles.csv")
n = pd.read_csv(str(rel_path) + r"\..\src\names_basics.csv")

# %% [markdown]
# ## Adding identifying information

# %%
od['imdbID'] = od['Bio IMDb'].str.split('/', expand = True)[4]
for tup in od:
    print(tup) 
# url = search(, tld='com', lang='en', num=10, start=0, stop=None, pause=2.0)
# for result in url:
#     print(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04331b0d66dc> in <module>
# ----> 1 od['imdbID'] = od['Bio IMDb'].str.split('/', expand = True)[4]
#       2 for tup in od:
#       3     print(tup)
#       4 # url = search(, tld='com', lang='en', num=10, start=0, stop=None, pause=2.0)
#       5 # for result in url:
#
# NameError: name 'od' is not defined

# %% [markdown]
# ## Adding Miscellaneous Information

# %%
# Out:
# 0

# %%
od
# Out:
#                                   Person Date of birth        Birthplace  \
# 0                          János Székely    1901-07-07          Budapest
# 1                             Elia Kazan    1909-09-07    Constantinople
# 2                             Elia Kazan    1909-09-07    Constantinople
# 3                             Elia Kazan    1909-09-07    Constantinople
# 4                             Elia Kazan    1909-09-07    Constantinople
# 5                             Elia Kazan    1909-09-07    Constantinople
# 6                             Elia Kazan    1909-09-07    Constantinople
# 7                           Dianne Wiest    1948-03-28       Kansas City
# 8                           Dianne Wiest    1948-03-28       Kansas City
# 9                         Dorothy Malone    1924-01-30           Chicago
# 10                        Dorothy Malone    1924-01-29           Chicago
# 11                           Grace Kelly    1929-11-12      Philadelphia
# ...
