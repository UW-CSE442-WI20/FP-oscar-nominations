# %% [markdown]
# # Title

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import pathlib as path

# %% [markdown]
# ## Importing Files

# %%
rel_path = path.Path().absolute()
oscars_demographics = pd.read_csv(str(rel_path) + r"\raw_data\oscars-demographics.csv", sep = ';')
mt = pd.read_csv(str(rel_path) + r"\processed_data\movie_titles.csv")

# %%
imdb_less= 0
oscars_demographics['Year of award'] = pd.to_numeric(oscars_demographics['Year of award'])
for m in oscars_demographics['Movie']:
    for y in oscars_demographics[oscars_demographics['Movie'] == m]['Year of award']:
        count = len(mt[(mt['primaryTitle'] == m) & (mt['startYear'] == y)])
        if count == 0:
            print(m + "\t" + str(y) + "\t" +str(count) + str(mt[mt['primaryTitle'] == m]['startYear']))
            imdb_less += 1
print(imdb_less)
# Out:
# Written on the Wind	1957	048300    1956.0
# Name: startYear, dtype: float64
# Written on the Wind	1957	048300    1956.0
# Name: startYear, dtype: float64
# Cool Hand Luke	1968	058468    1967.0
# Name: startYear, dtype: float64
# Anthony Adverse	1937	026828    1936.0
# Name: startYear, dtype: float64
# 20,000 Leagues Under the Sea	1955	0572        1907.0
# 6258       1916.0
# 45249      1954.0
# 105754     1997.0
# 309609     1973.0
# 338496     2004.0
# 373515     1985.0
# 477414        0.0
# 593173     1905.0
# 802137        0.0
# 857549     2008.0
# 1371724       0.0
# Name: startYear, dtype: float64
# 20,000 Leagues Under the Sea	1955	0572        1907.0
# 6258       1916.0
# 45249      1954.0
# 105754     1997.0
# 309609     1973.0
# 338496     2004.0
# 373515     1985.0
# 477414        0.0
# 593173     1905.0
# 802137        0.0
# 857549     2008.0
# 1371724       0.0
# Name: startYear, dtype: float64
# The Social Network	2011	0552793    2010.0
# Name: startYear, dtype: float64
# ...

# %%
mt[mt['primaryTitle'] == "The Revenant"]
# len(oscars_demographics)
# Out:
#         Unnamed: 0     tconst titleType  primaryTitle originalTitle  isAdult  \
# 561442      153157  tt1336006     movie  The Revenant  The Revenant        0
# 599903      303378  tt1491617     short  The Revenant  The Revenant        0
# 638400      468811  tt1663202     movie  The Revenant  The Revenant        0
# 706722      779596  tt1987669     short  The Revenant  The Revenant        0
# 850676      442898  tt3086948     short  The Revenant   Le revenant        0
# 873511      534656  tt3300078     movie  The Revenant  The Revenant        0
#
#         startYear  runtimeMinutes                      genres
# 561442     2009.0           117.0       Comedy,Fantasy,Horror
# 599903     2009.0            14.0                 Drama,Short
# 638400     2015.0           156.0  Action,Adventure,Biography
# 706722     2008.0            32.0                Action,Short
# 850676     2013.0             8.0        Comedy,Drama,Fantasy
# ...
