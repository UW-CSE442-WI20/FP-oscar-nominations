# %% [markdown]
# # Title

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import pathlib as path
from googlesearch import search

# %% [markdown]
# ## Importing Files

# %%
rel_path = path.Path().absolute()
od = pd.read_csv(str(rel_path) + r"\raw_data\oscars-demographics.csv", sep = ';')
od
# Out:
#                                   Person Date of birth  \
# 0                          János Székely    1901-07-07
# 1                             Elia Kazan    1909-09-07
# 2                           Dianne Wiest    1948-03-28
# 3                         Dorothy Malone    1924-01-30
# 4                            Grace Kelly    1929-11-12
# 5                            Jack Lemmon    1925-02-08
# 6                         George Kennedy    1925-02-18
# 7                         Melvyn Douglas    1901-04-05
# 8                              Burl Ives    1909-06-14
# 9                           Ralph Dawson    1897-04-18
# 10                         Carolyn Scott    2000-01-01
# 11                            Emile Kuri    1907-06-11
# 12                            Angus Wall    1967-03-15
# 13                          Adrien Brody    1973-04-14
# 14                         Michel Gondry    1963-05-08
# 15                            James Dunn    1901-11-02
# ...

# %% [markdown]
# ## Adding identifying information

# %%
od['imdbID'] = od['Bio IMDb'].str.split('/', expand = True)[4]
od['year_awarded'] = od['Year of award']
od['movieID'] = ''
# movie_search = 
for row in od.itertuples():
    print(f'{row.Movie} {row.year_awarded - 1} imdb')
    url = search(f'{row.Movie} {row.year_awarded - 1} imdb', tld='com', lang='en', num=1, start=0, stop=1, pause=0.01)
    for i in url:
        print(i)
        od.set_value(row.movieID, 'movieID', i)
# Out:
# Arise, My Love 1939 imdb
# https://www.imdb.com/title/tt0032220/
# On the Waterfront 1953 imdb
# C:\Users\wolf1\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# https://www.imdb.com/title/tt0047677/
# Hannah and Her Sisters 1985 imdb
# https://www.imdb.com/title/tt0091167/
# Written on the Wind 1956 imdb
# https://www.imdb.com/title/tt0049966/
# The Country Girl 1953 imdb
# https://www.imdb.com/title/tt0046874/
# Mister Roberts 1954 imdb
# https://www.imdb.com/title/tt0048380/
# Cool Hand Luke 1967 imdb
# https://www.imdb.com/title/tt0061512/
# Hud 1962 imdb
# https://www.imdb.com/title/tt0057163/
# The Big Country 1957 imdb
# https://www.imdb.com/title/tt0051411/
# Anthony Adverse 1935 imdb
# https://www.imdb.com/title/tt0027300/
# The Madness of King George 1993 imdb
# ...

# %% [markdown]
# ## Adding Miscellaneous Information

# %%
od[od['movieID'] != '']
# Out:
#  Person Date of birth Birthplace Country of birth Award Edition Movie  \
#     NaN           NaN        NaN              NaN   NaN     NaN   NaN
#
#   Year of award Bio NNDB Bio IMDb Bio Wikipedia imdbID  year_awarded  \
#             NaN      NaN      NaN           NaN    NaN           NaN
#
#                                 movieID
#   https://www.imdb.com/title/tt0467406/

# %%
# Out:
# 0

# %%
od
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4288309547bb> in <module>
# ----> 1 od
#
# NameError: name 'od' is not defined
